# %% [markdown]
# <a href="https://colab.research.google.com/github/GowthamRajgr27/ocr/blob/master/ocr_detector_and_recognizer_using_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training a custom OCR pipeline with keras-ocr

# %%
# @title

# !pip install -U opencv-python # We need the most recent version of OpenCV.
# To install from master
# !pip install git+https://github.com/GowthamRajgr27/ocr.git#egg=keras-ocr

# To install from PyPi
# !pip install keras-ocr
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
# Successfully installed opencv-python-4.9.0.80
# Collecting keras-ocr
#   Cloning https://github.com/GowthamRajgr27/ocr.git to /tmp/pip-install-ua5xzlku/keras-ocr_ffcb967c9ad248bf8776464801c01b47
#   Running command git clone --filter=blob:none --quiet https://github.com/GowthamRajgr27/ocr.git /tmp/pip-install-ua5xzlku/keras-ocr_ffcb967c9ad248bf8776464801c01b47
#   Resolved https://github.com/GowthamRajgr27/ocr.git to commit 14d2ce259f0fe9f4de1b1a87b8493083ac367e06
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (0.6.2)
# Collecting efficientnet==1.0.0 (from keras-ocr)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Collecting essential_generators (from keras-ocr)
#   Downloading essential_generators-1.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: fonttools in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (4.47.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (0.4.0)
# Collecting pyclipper (from keras-ocr)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 60.1 MB/s eta 0:00:00
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (4.66.1)
# Collecting validators (from keras-ocr)
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet==1.0.0->keras-ocr)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->keras-ocr) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (4.9.0.80)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (2.31.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras-ocr) (3.9.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (2.8.2)
# Building wheels for collected packages: keras-ocr
#   Building wheel for keras-ocr (pyproject.toml) ... done
#   Created wheel for keras-ocr: filename=keras_ocr-0.0.0-py3-none-any.whl size=42317 sha256=10712e736e0b2f80677b9abf318bfebfe97773d67c35ece4952b6ce19afa640d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0cgjizgi/wheels/33/ba/7b/3560d10ce7b758c79410a905b76fad9f6dc1df865971cc8f41
# Successfully built keras-ocr
# Installing collected packages: pyclipper, essential_generators, validators, keras-applications, efficientnet, keras-ocr
# Successfully installed efficientnet-1.0.0 essential_generators-1.0 keras-applications-1.0.8 keras-ocr-0.0.0 pyclipper-1.3.0.post5 validators-0.22.0
# Requirement already satisfied: keras-ocr in /usr/local/lib/python3.10/dist-packages (0.0.0)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (0.6.2)
# Requirement already satisfied: efficientnet==1.0.0 in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (1.0.0)
# Requirement already satisfied: essential_generators in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (1.0)
# Requirement already satisfied: fonttools in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (4.47.0)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (0.4.0)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (1.3.0.post5)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (4.66.1)
# Requirement already satisfied: validators in /usr/local/lib/python3.10/dist-packages (from keras-ocr) (0.22.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->keras-ocr) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->keras-ocr) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (4.9.0.80)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->keras-ocr) (2.31.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras-ocr) (3.9.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->keras-ocr) (2.8.2)

# %%
try:
  from google.colab import drive
  import os
  drive.mount('/content/drive')
  data_dir = '/colab/keras-ocr'
  os.makedirs(data_dir, exist_ok=True)
except ImportError:
  data_dir = '.'
# Out:
# Mounted at /content/drive

# %%
import zipfile
import datetime
import string
import glob
import math
import os

import tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn.model_selection

import keras_ocr

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Generating synthetic data
#
# First, we define the alphabet that encompasses all characters we want our model to be able to detect and recognize. Below we designate our alphabet as the numbers 0-9, upper- and lower-case letters, and a few puncuation marks. For the recognizer, we will actually only predict lowercase letters because we know some fonts print lower- and upper-case characters with the same glyph.
#
# In order to train on synthetic data, we require a set of fonts and backgrounds. `keras-ocr` includes a set of both of these which have been downloaded from Google Fonts and Wikimedia. The code to generate both of these sets is available in the repository under `scripts/create_fonts_and_backgrounds.py`.
#
# The fonts cover different languages which may have non-overlapping characters. `keras-ocr` supplies a function (`font_supports_alphabet`) to verify that a font includes the characters in an alphabet. We filter to only these fonts. We also exclude any fonts that are marked as `thin` in the filename because those tend to be difficult to render in a legible manner.
#
# The backgrounds folder contains about just over 1,000 image backgrounds.

# %%
alphabet = string.digits + string.ascii_letters + '!?. '
recognizer_alphabet = ''.join(sorted(set(alphabet.lower())))
fonts = keras_ocr.data_generation.get_fonts(
    alphabet=alphabet,
    cache_dir=data_dir
)
backgrounds = keras_ocr.data_generation.get_backgrounds(cache_dir=data_dir)
# Out:
# Looking for /colab/keras-ocr/fonts.zip
# Downloading /colab/keras-ocr/fonts.zip
# Unzipping fonts ZIP file.
# Filtering fonts.:  68%|██████▊   | 1860/2746 [01:18<00:18, 49.00it/s]WARNING:fontTools.ttLib.tables._p_o_s_t:58295 extra bytes in post.stringData array
# Filtering fonts.: 100%|██████████| 2746/2746 [01:57<00:00, 23.39it/s]
# Looking for /colab/keras-ocr/backgrounds.zip
# Downloading /colab/keras-ocr/backgrounds.zip

# %% [markdown]
# With a set of fonts, backgrounds, and alphabet, we now build our data generators.
#
# In order to create images, we need random strings. `keras-ocr` has a simple method for this for English, but anything that generates strings of characters in your selected alphabet will do!
#
# The image generator generates `(image, lines)` tuples where `image` is a HxWx3 image and `lines` is a list of lines of text in the image where each line is itself a list of tuples of the form `((x1, y1), (x2, y2), (x3, y3), (x4, y4), c)`. `c` is the character in the line and `(x1, y2), (x2, y2), (x3, y3),
# (x4, y4)` define the bounding coordinates in clockwise order starting from the top left. You can replace this with your own generator, just be sure to match that function signature.
#
# We split our generators into train, validation, and test by separating the fonts and backgrounds used in each.

# %%
text_generator = keras_ocr.data_generation.get_text_generator(alphabet=alphabet)
print('The first generated text is:', next(text_generator))

def get_train_val_test_split(arr):
    train, valtest = sklearn.model_selection.train_test_split(arr, train_size=0.8, random_state=42)
    val, test = sklearn.model_selection.train_test_split(valtest, train_size=0.5, random_state=42)
    return train, val, test

background_splits = get_train_val_test_split(backgrounds)
font_splits = get_train_val_test_split(fonts)

image_generators = [
    keras_ocr.data_generation.get_image_generator(
        height=640,
        width=640,
        text_generator=text_generator,
        font_groups={
            alphabet: current_fonts
        },
        backgrounds=current_backgrounds,
        font_size=(60, 120),
        margin=50,
        rotationX=(-0.05, 0.05),
        rotationY=(-0.05, 0.05),
        rotationZ=(-15, 15)
    )  for current_fonts, current_backgrounds in zip(
        font_splits,
        background_splits
    )
]

# See what the first validation image looks like.
image, lines = next(image_generators[1])
text = keras_ocr.data_generation.convert_lines_to_paragraph(lines)
print('The first generated validation image (below) contains:', text)
plt.imshow(image)
# Out:
# The first generated text is: Language can on this federal list.
# The first generated validation image (below) contains: Tarif
# fs betwe
# en Coa
# st Guar
# d

# %%
detector = keras_ocr.detection.Detector(weights='clovaai_general')
recognizer = keras_ocr.recognition.Recognizer(
    alphabet=recognizer_alphabet,
    weights='kurapan'
)
recognizer.compile()
for layer in recognizer.backbone.layers:
    layer.trainable = False
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Provided alphabet does not match pretrained alphabet. Using backbone weights only.
# Looking for /root/.keras-ocr/crnn_kurapan_notop.h5
# Downloading /root/.keras-ocr/crnn_kurapan_notop.h5

# %%
import keras_ocr
from tensorflow.keras.utils import plot_model

# Create an instance of the Keras OCR pipeline
pipeline = keras_ocr.pipeline.Pipeline()

# Get the detector and recognizer models
detector_model = pipeline.detector.model
recognizer_model = pipeline.recognizer.model

# Display the summary of the detector model
print("Detector Model Summary:")
detector_model.summary()

# Display the summary of the recognizer model
print("\nRecognizer Model Summary:")
recognizer_model.summary()

# Optionally, you can save the model architecture plots
plot_model(detector_model, to_file='detector_model.png', show_shapes=True, show_layer_names=True)
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# Detector Model Summary:
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_12 (InputLayer)       [(None, None, None, 3)]      0         []
#
#  basenet.slice1.0 (Conv2D)   (None, None, None, 64)       1792      ['input_12[0][0]']
#
#  basenet.slice1.1 (BatchNor  (None, None, None, 64)       256       ['basenet.slice1.0[0][0]']
#  malization)
#
#  basenet.slice1.2 (Activati  (None, None, None, 64)       0         ['basenet.slice1.1[0][0]']
#  on)
#
#  basenet.slice1.3 (Conv2D)   (None, None, None, 64)       36928     ['basenet.slice1.2[0][0]']
#
#  basenet.slice1.4 (BatchNor  (None, None, None, 64)       256       ['basenet.slice1.3[0][0]']
#  malization)
#
#  basenet.slice1.5 (Activati  (None, None, None, 64)       0         ['basenet.slice1.4[0][0]']
#  on)
#
#  basenet.slice1.6 (MaxPooli  (None, None, None, 64)       0         ['basenet.slice1.5[0][0]']
#  ng2D)
#
#  basenet.slice1.7 (Conv2D)   (None, None, None, 128)      73856     ['basenet.slice1.6[0][0]']
#
#  basenet.slice1.8 (BatchNor  (None, None, None, 128)      512       ['basenet.slice1.7[0][0]']
#  malization)
#
#  basenet.slice1.9 (Activati  (None, None, None, 128)      0         ['basenet.slice1.8[0][0]']
#  on)
#
#  basenet.slice1.10 (Conv2D)  (None, None, None, 128)      147584    ['basenet.slice1.9[0][0]']
#
#  basenet.slice1.11 (BatchNo  (None, None, None, 128)      512       ['basenet.slice1.10[0][0]']
#  rmalization)
#
#  basenet.slice1.12 (Activat  (None, None, None, 128)      0         ['basenet.slice1.11[0][0]']
#  ion)
#
#  basenet.slice1.13 (MaxPool  (None, None, None, 128)      0         ['basenet.slice1.12[0][0]']
#  ing2D)
#
#  basenet.slice2.14 (Conv2D)  (None, None, None, 256)      295168    ['basenet.slice1.13[0][0]']
#
#  basenet.slice2.15 (BatchNo  (None, None, None, 256)      1024      ['basenet.slice2.14[0][0]']
#  rmalization)
#
#  basenet.slice2.16 (Activat  (None, None, None, 256)      0         ['basenet.slice2.15[0][0]']
#  ion)
#
#  basenet.slice2.17 (Conv2D)  (None, None, None, 256)      590080    ['basenet.slice2.16[0][0]']
#
#  basenet.slice2.18 (BatchNo  (None, None, None, 256)      1024      ['basenet.slice2.17[0][0]']
#  rmalization)
#
#  basenet.slice2.19 (Activat  (None, None, None, 256)      0         ['basenet.slice2.18[0][0]']
#  ion)
#
#  basenet.slice3.20 (Conv2D)  (None, None, None, 256)      590080    ['basenet.slice2.19[0][0]']
#
#  basenet.slice3.21 (BatchNo  (None, None, None, 256)      1024      ['basenet.slice3.20[0][0]']
#  rmalization)
#
#  basenet.slice3.22 (Activat  (None, None, None, 256)      0         ['basenet.slice3.21[0][0]']
#  ion)
#
#  basenet.slice3.23 (MaxPool  (None, None, None, 256)      0         ['basenet.slice3.22[0][0]']
#  ing2D)
#
#  basenet.slice3.24 (Conv2D)  (None, None, None, 512)      1180160   ['basenet.slice3.23[0][0]']
#
#  basenet.slice3.25 (BatchNo  (None, None, None, 512)      2048      ['basenet.slice3.24[0][0]']
#  rmalization)
#
#  basenet.slice3.26 (Activat  (None, None, None, 512)      0         ['basenet.slice3.25[0][0]']
#  ion)
#
#  basenet.slice3.27 (Conv2D)  (None, None, None, 512)      2359808   ['basenet.slice3.26[0][0]']
#
#  basenet.slice3.28 (BatchNo  (None, None, None, 512)      2048      ['basenet.slice3.27[0][0]']
#  rmalization)
#
#  basenet.slice3.29 (Activat  (None, None, None, 512)      0         ['basenet.slice3.28[0][0]']
#  ion)
#
#  basenet.slice4.30 (Conv2D)  (None, None, None, 512)      2359808   ['basenet.slice3.29[0][0]']
#
#  basenet.slice4.31 (BatchNo  (None, None, None, 512)      2048      ['basenet.slice4.30[0][0]']
#  rmalization)
#
#  basenet.slice4.32 (Activat  (None, None, None, 512)      0         ['basenet.slice4.31[0][0]']
#  ion)
#
#  basenet.slice4.33 (MaxPool  (None, None, None, 512)      0         ['basenet.slice4.32[0][0]']
#  ing2D)
#
#  basenet.slice4.34 (Conv2D)  (None, None, None, 512)      2359808   ['basenet.slice4.33[0][0]']
#
#  basenet.slice4.35 (BatchNo  (None, None, None, 512)      2048      ['basenet.slice4.34[0][0]']
#  rmalization)
#
#  basenet.slice4.36 (Activat  (None, None, None, 512)      0         ['basenet.slice4.35[0][0]']
#  ion)
#
#  basenet.slice4.37 (Conv2D)  (None, None, None, 512)      2359808   ['basenet.slice4.36[0][0]']
#
#  basenet.slice4.38 (BatchNo  (None, None, None, 512)      2048      ['basenet.slice4.37[0][0]']
#  rmalization)
#
#  basenet.slice5.0 (MaxPooli  (None, None, None, 512)      0         ['basenet.slice4.38[0][0]']
#  ng2D)
#
#  basenet.slice5.1 (Conv2D)   (None, None, None, 1024)     4719616   ['basenet.slice5.0[0][0]']
#
#  basenet.slice5.2 (Conv2D)   (None, None, None, 1024)     1049600   ['basenet.slice5.1[0][0]']
#
#  concatenate_14 (Concatenat  (None, None, None, 1536)     0         ['basenet.slice5.2[0][0]',
#  e)                                                                  'basenet.slice4.38[0][0]']
#
#  upconv1.conv.0 (Conv2D)     (None, None, None, 512)      786944    ['concatenate_14[0][0]']
#
#  upconv1.conv.1 (BatchNorma  (None, None, None, 512)      2048      ['upconv1.conv.0[0][0]']
#  lization)
#
#  upconv1.conv.2 (Activation  (None, None, None, 512)      0         ['upconv1.conv.1[0][0]']
#  )
#
#  upconv1.conv.3 (Conv2D)     (None, None, None, 256)      1179904   ['upconv1.conv.2[0][0]']
#
#  upconv1.conv.4 (BatchNorma  (None, None, None, 256)      1024      ['upconv1.conv.3[0][0]']
#  lization)
#
#  upconv1.conv.5 (Activation  (None, None, None, 256)      0         ['upconv1.conv.4[0][0]']
#  )
#
#  upsample_like_9 (UpsampleL  (None, None, None, 256)      0         ['upconv1.conv.5[0][0]',
#  ike)                                                                'basenet.slice3.29[0][0]']
#
#  concatenate_15 (Concatenat  (None, None, None, 768)      0         ['upsample_like_9[0][0]',
#  e)                                                                  'basenet.slice3.29[0][0]']
#
#  upconv2.conv.0 (Conv2D)     (None, None, None, 256)      196864    ['concatenate_15[0][0]']
#
#  upconv2.conv.1 (BatchNorma  (None, None, None, 256)      1024      ['upconv2.conv.0[0][0]']
#  lization)
#
#  upconv2.conv.2 (Activation  (None, None, None, 256)      0         ['upconv2.conv.1[0][0]']
#  )
#
#  upconv2.conv.3 (Conv2D)     (None, None, None, 128)      295040    ['upconv2.conv.2[0][0]']
#
#  upconv2.conv.4 (BatchNorma  (None, None, None, 128)      512       ['upconv2.conv.3[0][0]']
#  lization)
#
#  upconv2.conv.5 (Activation  (None, None, None, 128)      0         ['upconv2.conv.4[0][0]']
#  )
#
#  upsample_like_10 (Upsample  (None, None, None, 128)      0         ['upconv2.conv.5[0][0]',
#  Like)                                                               'basenet.slice2.19[0][0]']
#
#  concatenate_16 (Concatenat  (None, None, None, 384)      0         ['upsample_like_10[0][0]',
#  e)                                                                  'basenet.slice2.19[0][0]']
#
#  upconv3.conv.0 (Conv2D)     (None, None, None, 128)      49280     ['concatenate_16[0][0]']
#
#  upconv3.conv.1 (BatchNorma  (None, None, None, 128)      512       ['upconv3.conv.0[0][0]']
#  lization)
#
#  upconv3.conv.2 (Activation  (None, None, None, 128)      0         ['upconv3.conv.1[0][0]']
#  )
#
#  upconv3.conv.3 (Conv2D)     (None, None, None, 64)       73792     ['upconv3.conv.2[0][0]']
#
#  upconv3.conv.4 (BatchNorma  (None, None, None, 64)       256       ['upconv3.conv.3[0][0]']
#  lization)
#
#  upconv3.conv.5 (Activation  (None, None, None, 64)       0         ['upconv3.conv.4[0][0]']
#  )
#
#  upsample_like_11 (Upsample  (None, None, None, 64)       0         ['upconv3.conv.5[0][0]',
#  Like)                                                               'basenet.slice1.12[0][0]']
#
#  concatenate_17 (Concatenat  (None, None, None, 192)      0         ['upsample_like_11[0][0]',
#  e)                                                                  'basenet.slice1.12[0][0]']
#
#  upconv4.conv.0 (Conv2D)     (None, None, None, 64)       12352     ['concatenate_17[0][0]']
#
#  upconv4.conv.1 (BatchNorma  (None, None, None, 64)       256       ['upconv4.conv.0[0][0]']
#  lization)
#
#  upconv4.conv.2 (Activation  (None, None, None, 64)       0         ['upconv4.conv.1[0][0]']
#  )
#
#  upconv4.conv.3 (Conv2D)     (None, None, None, 32)       18464     ['upconv4.conv.2[0][0]']
#
#  upconv4.conv.4 (BatchNorma  (None, None, None, 32)       128       ['upconv4.conv.3[0][0]']
#  lization)
#
#  upconv4.conv.5 (Activation  (None, None, None, 32)       0         ['upconv4.conv.4[0][0]']
#  )
#
#  conv_cls.0 (Conv2D)         (None, None, None, 32)       9248      ['upconv4.conv.5[0][0]']
#
#  conv_cls.1 (Activation)     (None, None, None, 32)       0         ['conv_cls.0[0][0]']
#
#  conv_cls.2 (Conv2D)         (None, None, None, 32)       9248      ['conv_cls.1[0][0]']
#
#  conv_cls.3 (Activation)     (None, None, None, 32)       0         ['conv_cls.2[0][0]']
#
#  conv_cls.4 (Conv2D)         (None, None, None, 16)       4624      ['conv_cls.3[0][0]']
#
#  conv_cls.5 (Activation)     (None, None, None, 16)       0         ['conv_cls.4[0][0]']
#
#  conv_cls.6 (Conv2D)         (None, None, None, 16)       272       ['conv_cls.5[0][0]']
#
#  conv_cls.7 (Activation)     (None, None, None, 16)       0         ['conv_cls.6[0][0]']
#
#  conv_cls.8 (Conv2D)         (None, None, None, 2)        34        ['conv_cls.7[0][0]']
#
# ==================================================================================================
# Total params: 20780770 (79.27 MB)
# Trainable params: 20770466 (79.23 MB)
# Non-trainable params: 10304 (40.25 KB)
# __________________________________________________________________________________________________
#
# Recognizer Model Summary:
# Model: "model_20"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 31, 200, 1)]         0         []
#
#  permute_2 (Permute)         (None, 200, 31, 1)           0         ['input_13[0][0]']
#
#  lambda_8 (Lambda)           (None, 200, 31, 1)           0         ['permute_2[0][0]']
#
#  conv_1 (Conv2D)             (None, 200, 31, 64)          640       ['lambda_8[0][0]']
#
#  conv_2 (Conv2D)             (None, 200, 31, 128)         73856     ['conv_1[0][0]']
#
#  conv_3 (Conv2D)             (None, 200, 31, 256)         295168    ['conv_2[0][0]']
#
#  bn_3 (BatchNormalization)   (None, 200, 31, 256)         1024      ['conv_3[0][0]']
#
#  maxpool_3 (MaxPooling2D)    (None, 100, 15, 256)         0         ['bn_3[0][0]']
#
#  conv_4 (Conv2D)             (None, 100, 15, 256)         590080    ['maxpool_3[0][0]']
#
#  conv_5 (Conv2D)             (None, 100, 15, 512)         1180160   ['conv_4[0][0]']
#
#  bn_5 (BatchNormalization)   (None, 100, 15, 512)         2048      ['conv_5[0][0]']
#
#  maxpool_5 (MaxPooling2D)    (None, 50, 7, 512)           0         ['bn_5[0][0]']
#
#  conv_6 (Conv2D)             (None, 50, 7, 512)           2359808   ['maxpool_5[0][0]']
#
#  conv_7 (Conv2D)             (None, 50, 7, 512)           2359808   ['conv_6[0][0]']
#
#  bn_7 (BatchNormalization)   (None, 50, 7, 512)           2048      ['conv_7[0][0]']
#
#  model_18 (Functional)       (None, 6)                    934902    ['bn_7[0][0]']
#
#  lambda_9 (Lambda)           (None, 50, 7, 512)           0         ['bn_7[0][0]',
#                                                                      'model_18[0][0]']
#
#  reshape (Reshape)           (None, 50, 3584)             0         ['lambda_9[0][0]']
#
#  fc_9 (Dense)                (None, 50, 128)              458880    ['reshape[0][0]']
#
#  lstm_10 (LSTM)              (None, 50, 128)              131584    ['fc_9[0][0]']
#
#  lstm_10_back (LSTM)         (None, 50, 128)              131584    ['fc_9[0][0]']
#
#  add_2 (Add)                 (None, 50, 128)              0         ['lstm_10[0][0]',
#                                                                      'lstm_10_back[0][0]']
#
#  lstm_11 (LSTM)              (None, 50, 128)              131584    ['add_2[0][0]']
#
#  lstm_11_back (LSTM)         (None, 50, 128)              131584    ['add_2[0][0]']
#
#  concatenate_18 (Concatenat  (None, 50, 256)              0         ['lstm_11[0][0]',
#  e)                                                                  'lstm_11_back[0][0]']
#
#  dropout (Dropout)           (None, 50, 256)              0         ['concatenate_18[0][0]']
#
#  fc_12 (Dense)               (None, 50, 37)               9509      ['dropout[0][0]']
#
#  lambda_10 (Lambda)          (None, 48, 37)               0         ['fc_12[0][0]']
#
# ==================================================================================================
# Total params: 8794267 (33.55 MB)
# Trainable params: 8791707 (33.54 MB)
# Non-trainable params: 2560 (10.00 KB)
# __________________________________________________________________________________________________

# %%
plot_model(recognizer_model, to_file='recognizer_model.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# We are now ready to train our text detector. Below we use some simple defaults.
#
# - Run training until we have no improvement on the validation set for 5 epochs.
# - Save the best weights.
# - For each epoch, iterate over all backgrounds one time.
#
# The `detector` object has a `get_batch_generator` method which converts the `image_generator` (which returns images and associated annotations) into a `batch_generator` that returns `X, y` pairs for training with `fit_generator`.
#
# If training on Colab and it assigns you a K80, you can only use batch size 1. But if you get a T4 or P100, you can use larger batch sizes.

# %%
detector_batch_size = 1
detector_basepath = os.path.join(data_dir, f'detector_{datetime.datetime.now().isoformat()}')
detection_train_generator, detection_val_generator, detection_test_generator = [
    detector.get_batch_generator(
        image_generator=image_generator,
        batch_size=detector_batch_size
    ) for image_generator in image_generators
]
detector.model.fit(
    x=detection_train_generator,
    steps_per_epoch=math.ceil(len(background_splits[0]) / detector_batch_size),
    epochs=5,
    workers=0,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(restore_best_weights=True, patience=5),
        tf.keras.callbacks.CSVLogger(f'{detector_basepath}.csv'),
        tf.keras.callbacks.ModelCheckpoint(filepath=f'{detector_basepath}.h5')
    ],
    validation_data=detection_val_generator,
    validation_steps=math.ceil(len(background_splits[1]) / detector_batch_size)
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras_ocr/tools.py:580: RuntimeWarning: invalid value encountered in float_scalars
#   rotation = np.arctan((tl[0] - bl[0]) / (tl[1] - bl[1]))
# 827/827 [==============================] - ETA: 0s - loss: 0.0082
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 827/827 [==============================] - 409s 459ms/step - loss: 0.0082 - val_loss: 0.0100
# Epoch 2/5
# 827/827 [==============================] - 382s 462ms/step - loss: 0.0060 - val_loss: 0.0107
# Epoch 3/5
# 827/827 [==============================] - 381s 461ms/step - loss: 0.0060 - val_loss: 0.0107
# Epoch 4/5
# 827/827 [==============================] - 373s 451ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 5/5
# 827/827 [==============================] - 381s 461ms/step - loss: 0.0049 - val_loss: 0.0056

# %% [markdown]
# After training the text detector, we train the recognizer. Note that the recognizer expects images
# to already be cropped to single lines of text. :code:`keras-ocr` provides a convenience method for
# converting our existing generator into a single-line generator. So we perform that conversion.

# %%
max_length = 10
recognition_image_generators = [
    keras_ocr.data_generation.convert_image_generator_to_recognizer_input(
        image_generator=image_generator,
        max_string_length=min(recognizer.training_model.input_shape[1][1], max_length),
        target_width=recognizer.model.input_shape[2],
        target_height=recognizer.model.input_shape[1],
        margin=1
    ) for image_generator in image_generators
]

# See what the first validation image for recognition training looks like.
image, text = next(recognition_image_generators[1])
print('This image contains:', text)
plt.imshow(image)
# Out:
# This image contains: electrom

# %% [markdown]
# Just like the `detector`, the :code:`recognizer` has a method for converting the image generator
# into a `batch_generator` that Keras' `fit_generator` can use.
#
# We use the same callbacks for early stopping and logging as before.

# %%
recognition_batch_size = 8
recognizer_basepath = os.path.join(data_dir, f'recognizer_{datetime.datetime.now().isoformat()}')
recognition_train_generator, recognition_val_generator, recogntion_test_generator = [
    recognizer.get_batch_generator(
      image_generator=image_generator,
      batch_size=recognition_batch_size,
      lowercase=True
    ) for image_generator in recognition_image_generators
]
recognizer.training_model.fit(
    recognition_train_generator,
    epochs=5,
    steps_per_epoch=math.ceil(len(background_splits[0]) / recognition_batch_size),
    callbacks=[
        tf.keras.callbacks.EarlyStopping(restore_best_weights=True, patience=25),
        tf.keras.callbacks.CSVLogger(f'{recognizer_basepath}.csv', append=True),
        tf.keras.callbacks.ModelCheckpoint(filepath=f'{recognizer_basepath}.h5')
    ],
    validation_data=recognition_val_generator,
    validation_steps=math.ceil(len(background_splits[1]) / recognition_batch_size),
    workers=0,
    batch_size=recognition_batch_size  # Corrected spelling here
)

# %% [markdown]
# Once training is done, you can use `recognize` to extract text.

# %%
pipeline = keras_ocr.pipelines.Pipeline(detector=detector, recognizer=recognizer)
image, lines = next(image_generators[0])
predictions = pipeline.recognize(images=[image])[0]
drawn = keras_ocr.tools.drawBoxes(
    image=image, boxes=predictions, boxes_format='predictions'
)
print(
    'Actual:', '\n'.join([' '.join([character for _, character in line]) for line in lines]),
    'Predicted:', [text for text, box in predictions])
plt.imshow(drawn)
# Out:
# Snowcraft and Austrian descent? ['s', 'nowcraft', 'and', 'aus', 'trian', 'descent']

# %%
# !curl https://raw.githubusercontent.com/faustomorales/keras-ocr/master/tests/test_image.jpg --output test_image.jpg
image = keras_ocr.tools.read('test_image.jpg')
boxes = detector.detect(images=[image])[0]
drawn = keras_ocr.detection.drawBoxes(image=image, boxes=boxes)
plt.imshow(drawn)

# %% [markdown]
# Let's save our trained pipeline and download it

# %%
import keras_ocr
import shutil
from google.colab import files

from tensorflow.keras.models import load_model
import pickle

detector_model = pipeline.detector.model
recognizer_model = pipeline.recognizer.model

pickle.dump(detector_model,open("C:\\Users\\manis\\project\\models\\detector.pkl",'wb'))
pickle.dump(recognizer_model,open("C:\\Users\\manis\\project\\models\\recognizer.pkl",'wb'))
# Save models
#detector_model.save('detector_model.h5')
